# %% [markdown]
# White wine model analysis
# 1. Load the data
# 2. Data Wrangling
# 3. Split your data
# 4. Normalize vs Standardization
# 5. RobustScaler data having outliers otherwise StandardScaler
#
# Check Standardization code for normalized value

# %%
#load white wine data
import pandas as pd
#white_wine = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv', sep=';')
white_wine = pd.read_csv('/Users/macbookair/Downloads/winequality-white.csv', sep=';')
white_wine.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
#check for null values in white wine
white_wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
white_wine.describe().T
# Out:
#                        count        mean        std      min         25%  \
# fixed acidity         4898.0    6.854788   0.843868  3.80000    6.300000
# volatile acidity      4898.0    0.278241   0.100795  0.08000    0.210000
# citric acid           4898.0    0.334192   0.121020  0.00000    0.270000
# residual sugar        4898.0    6.391415   5.072058  0.60000    1.700000
# chlorides             4898.0    0.045772   0.021848  0.00900    0.036000
# free sulfur dioxide   4898.0   35.308085  17.007137  2.00000   23.000000
# total sulfur dioxide  4898.0  138.360657  42.498065  9.00000  108.000000
# density               4898.0    0.994027   0.002991  0.98711    0.991723
# pH                    4898.0    3.188267   0.151001  2.72000    3.090000
# sulphates             4898.0    0.489847   0.114126  0.22000    0.410000
# alcohol               4898.0   10.514267   1.230621  8.00000    9.500000
# quality               4898.0    5.877909   0.885639  3.00000    5.000000
#
# ...

# %%
white_wine.shape
# Out:
# (4898, 12)

# %%
# we are splitting the data in 0/1/2 
#Y = white_wine['quality'].apply(lambda value: 0 if value <= 5 else 1 if value <= 6 else 2)
# Set quality label as 0 for quality range (1-5) ; 1 for quality value 6; 2 for quality range (7-9)
white_wine['quality'] = white_wine['quality'].apply(lambda value: 0 if value <= 5 else 1 if value <= 6 else 2)
#white_wine = white_wine.drop(columns=['quality'])
#white_wine = white_wine.drop('quality', axis =1)
Y = white_wine['quality'] 
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: quality, dtype: int64

# %%
X = white_wine.drop(columns=['quality'], axis=1) 
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol
# 0      8.8
# 1      9.5
# 2     10.1
# 3      9.9
# 4      9.9

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state= 2 )

# %%
#Standardization - 
from sklearn.preprocessing import StandardScaler
norm = StandardScaler().fit(X_train)

# transform training data
#X_train = norm.transform(X_train)
X_train_norm = norm.transform(X_train)

# transform testing data
X_test_norm = norm.transform(X_test)
#X_test = norm.transform(X_test)

# %%
from imblearn.over_sampling import SMOTE
os = SMOTE()
X_res, Y_res = os.fit_resample(X,Y)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn= KNeighborsClassifier()
knn.fit(X_train, Y_train)
from sklearn.metrics import accuracy_score
X_test_prediction = knn.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print ('test_data_accuracy: ', test_data_accuracy)

from sklearn.metrics import classification_report
print(classification_report(Y_test, X_test_prediction, target_names=["low","medium", "high"]))

from sklearn.metrics import cohen_kappa_score
kappa = cohen_kappa_score(X_test_prediction, Y_test)
print("Cohen-Kappa score:", kappa)
# Out:
# test_data_accuracy:  0.48673469387755103
#               precision    recall  f1-score   support
#
#          low       0.50      0.54      0.52       342
#       medium       0.49      0.51      0.50       432
#         high       0.44      0.35      0.39       206
#
#     accuracy                           0.49       980
#    macro avg       0.48      0.47      0.47       980
# weighted avg       0.48      0.49      0.48       980
#
# Cohen-Kappa score: 0.18699964705222627

# %%
from sklearn.linear_model import LogisticRegression
# Fit the model
lr = LogisticRegression()
lr.fit(X_train, Y_train)

# Make predictions
pred_lr = lr.predict(X_test)

from sklearn.metrics import confusion_matrix
print("Confusion matrix:")
print(confusion_matrix(Y_test, pred_lr))

from sklearn.metrics import accuracy_score
print("Accuracy score:", accuracy_score(Y_test, pred_lr))

from sklearn.metrics import classification_report
print(classification_report(Y_test, pred_lr, target_names=["low","medium", "high"]))

from sklearn.metrics import cohen_kappa_score
kappa = cohen_kappa_score(pred_lr, Y_test)
print("Cohen-Kappa score:", kappa)
# Out:
# Confusion matrix:
# [[149 188   5]
#  [ 95 296  41]
#  [ 24 143  39]]
# Accuracy score: 0.49387755102040815
#               precision    recall  f1-score   support
#
#          low       0.56      0.44      0.49       342
#       medium       0.47      0.69      0.56       432
#         high       0.46      0.19      0.27       206
#
#     accuracy                           0.49       980
#    macro avg       0.50      0.44      0.44       980
# weighted avg       0.50      0.49      0.47       980
#
# Cohen-Kappa score: 0.16246532384513324
# /Users/macbookair/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rfc= RandomForestClassifier()
rfc.fit(X_train, Y_train)
from sklearn.metrics import accuracy_score
X_test_prediction = rfc.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print ('test_data_accuracy: ', test_data_accuracy)

from sklearn.metrics import classification_report
print(classification_report(Y_test, X_test_prediction, target_names=["low","medium", "high"]))

from sklearn.metrics import cohen_kappa_score
kappa = cohen_kappa_score(X_test_prediction, Y_test)
print("Cohen-Kappa score:", kappa)
# Out:
# test_data_accuracy:  0.7122448979591837
#               precision    recall  f1-score   support
#
#          low       0.77      0.72      0.74       342
#       medium       0.66      0.77      0.71       432
#         high       0.78      0.59      0.67       206
#
#     accuracy                           0.71       980
#    macro avg       0.73      0.69      0.71       980
# weighted avg       0.72      0.71      0.71       980
#
# Cohen-Kappa score: 0.5401709799902163
